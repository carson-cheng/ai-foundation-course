# %% [markdown]
# # Python and ML exercise
# - Now that we've come this far in terms of learning the basic concepts of machine learning, let's revise what we learned in the first 5 sessions before we move on.

# %% [markdown]
# # Task 1: Python loops, functions, and data structures
# - a. Print out all integers from 1 to 100 inclusive in the notebook.

# %%
# task 1a -- your code here

# %% [markdown]
# - b. Write a function that accepts an input x, and outputs x^2

# %%
# task 1b -- your code here
def square(x):
    # your code here
print(square(3)) # 9
print(square(5)) # 25
print(square(7)) # 49

# %% [markdown]
# - c. A list a = [1, 2, 3, 4, 5] is given below. Shuffle the list randomly.

# %%
import random
a = [1, 2, 3, 4, 5]
# your code here
print(a) # you should get a shuffled list, containing the same elements but in a random order

# %% [markdown]
# # Task 2: Basic ML concepts

# %% [markdown]
# a. If your model has good performance on training data but poor performance on validation data, what is this phenomenon?
#
# A. Undertraining\
# B. Overtraining\
# C. Underfitting\
# D. Overfitting
#
# Your answer: ___
#
# b. If your model performs well on training data but not on validation data, how can you solve this problem?
#
# A. Collect more data\
# B. Reduce the model complexity\
# C. Assess and improve the data quality\
# D. All of the above
#
# Your answer: ___
#
# c. Which of the following enables visualization of high-dimensional data into a scatterplot?
#
# A. PCA\
# B. Linear regression\
# C. Logistic regression\
# D. Random forest
#
# Your answer: ___
#
# d. Why is feature engineering important?
#
# A. It helps an activation function operate\
# B. It provides informative features that can greatly assist in modeling\
# C. It destroys the quality of the data\
# D. All of the above
#
# Your answer: ____

# %% [markdown]
# # Task 3: Data processing and visualization

# %%
import pandas as pd
error_msg = '''# have to download https://www.kaggle.com/datasets/zeeshier/weather-forecast-dataset first
# alternatively go to https://www.kaggle.com/code/carsoncheng/classwork-1'''
df = None
try:
    global df
    df = pd.read_csv("/kaggle/input/weather-forecast-dataset/weather_forecast_data.csv")
except:
    print(error_msg)
df.head()
# Out:
#    Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0    23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1    27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2    25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3    23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4    20.591370  96.858822    4.643921    47.676444   980.825142  no rain

# %% [markdown]
# - a. How many percent of data points have no rain?

# %%
# your code here
print() # should output 0.8744 (corresponding to 87.44%)
# Out:
# 0.8744

# %% [markdown]
# - b. Assign all feature columns in the data to X, and assign all label columns in the data to y\
#   (hint: we're predicting whether for a certain weather condition, whether there's rain or not)

# %%
feature_columns = ['Temperature', 'Humidity', 'Wind_Speed', 'Cloud_Cover', 'Pressure']
label_columns = ['Rain']
X = # your code here

# %% [markdown]
# - c. Use StandardScaler to normalize the features

# %%
from sklearn.preprocessing import StandardScaler
X_normalized = # your code here

# %% [markdown]
# - d. Use PCA to plot the normalized features

# %%
from sklearn.decomposition import PCA
import seaborn as sns
pca = PCA(n_components=2)
X_transformed = ## your code here
sns.scatterplot(x=X_transformed[:,0])

# %% [markdown]
# - e. Split the data into train, validation, and test with 3:1:1 ratio

# %%
# your code here

# %% [markdown]
# - Bonus tasks
# - f. use a model you like to classify the data<br>
# - g. then write a short description about how well your model classifies the data, referring to different metrics for your classification

# %%
# your code here
