# %% [markdown]
# # Session 1-3 Homework
# After sessions 1-3, you should be able to understand basic numpy array manipulations, train test split, as well as training and evaluating basic machine learning models.

# %% [markdown]
# # Part A: Numpy array processing

# %%
import numpy as np
#1.create an arbitrary array of size (3,2,3) (1 mark)
arr1=#your code here
print(arr1.size)
#2.consider arr2. Make every element of arr2 be 67 (1 mark)
arr2=np.array([[1675,1675,1675,1675],[1675,1675,1675,1675],[1675,1675,1675,1675]])
print(#Your code here)
#3.flatten arr2 (1 mark)
    #your code here
#4.consider arr3 and arr4. Multiply arr3 and arr4 (1 mark)
# Note: use matrix multiplication, not element-wise multiplication
arr3 = np.random.randn(4,5)
arr4 = np.random.randn(5,4)
print(#your code here)

# %% [markdown]
# # Part B: Regression (predict house prices)
# Houses are not cheap.

# %% [markdown]
# Task 1: import the dataset and observe some of the data (hint-import the data.csv file drom housedata) (1 mark)

# %%
import pandas as pd
# download https://www.kaggle.com/datasets/lailaicoding/housedata-cleaned 
df= #your code here
df.head()

# %% [markdown]
# Task 2.1: split the dataframe into features(X) and target(Y) <br> (1 mark)
# Task 2.2: Split X and Y into train, test, validation sets in 3:1:1 ratio (2 marks)

# %%
from sklearn.model_selection import train_test_split
#your code here



print(len(X_train), len(X_val), len(X_test))

# %% [markdown]
# Task 3: Model contruction and training<br>
# * a) Contruct a regression model of your choice (refer to the slides for the pros/cons of each model or search for other models online) (1 mark)
# * b) Fit the training data into the model. (1 mark)
# * c) Create a report on the evaluation of the model (eg. metrics, overfit/underfit) (2 marks)
# * d) Which feature is the most important? (1 mark)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
#your code here

# %% [markdown]
# # Part C: Classification (stroke)
# r/ihaveastroke

# %% [markdown]
# Task 1: import the dataset and observe some of the data (hint-no hints this time!) (1 mark)

# %%
import pandas as pd
# download https://www.kaggle.com/datasets/lailaicoding/stroke-data-cleaned 
df=#your code here
df.head()

# %% [markdown]
# Task 2: same as task 2 in regression part (3 marks)

# %%
from sklearn.model_selection import train_test_split
#your code here



print(len(X_train), len(X_val), len(X_test))

# %% [markdown]
# Task 3: Model contruction and training<br>
# * a) Contruct a classification model of your choice (refer to the slides for the pros/cons of each model or search for other models online) (1 mark)
# * b) Fit the training data into the model. (1 mark)
# * c) Create a report on the evaluation of the model (analyzing different classification metrics) (2 marks)
